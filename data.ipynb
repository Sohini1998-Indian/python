# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('./loan_data_set.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
def missing_group(d):
    for col in d.columns:
        print("Missing percentage for column",col,round((d[col].isnull().sum()/len(d[col])*100),0),"%")
missing_group(data)
# Out:
# Missing percentage for column Loan_ID 0.0 %
# Missing percentage for column Gender 2.0 %
# Missing percentage for column Married 0.0 %
# Missing percentage for column Dependents 2.0 %
# Missing percentage for column Education 0.0 %
# Missing percentage for column Self_Employed 5.0 %
# Missing percentage for column ApplicantIncome 0.0 %
# Missing percentage for column CoapplicantIncome 0.0 %
# Missing percentage for column LoanAmount 4.0 %
# Missing percentage for column Loan_Amount_Term 2.0 %
# Missing percentage for column Credit_History 8.0 %
# Missing percentage for column Property_Area 0.0 %
# Missing percentage for column Loan_Status 0.0 %

# %% [markdown]
# # Missing Data Visualization

# %%
import missingno as msno 

msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
num_col=["LoanAmount","Loan_Amount_Term","Credit_History"]

for i in data.columns:
    if i in num_col:
        data[i].fillna(data[i].mean(),inplace=True)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
cat_col=["Gender","Dependents","Self_Employed","Married"]

for i in data.columns:
    if i in cat_col:
        data[i].fillna(data[i].mode()[0],inplace=True)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
x=data.iloc[: , :-1]
y=data["Loan_Status"].map(dict(Y=1, N=0))

# x.plot(kind="box",subplots=True,figsize=(15,20),layout=(6,2))
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(data['Credit_History'], data['Gender'])
 
# x-axis label
ax.set_xlabel('Credit_History')
 
# y-axis label
ax.set_ylabel("Gender")
plt.show()

# %%
import math

def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers
outliers=find_outliers_IQR(data)

# print("number of outliers: "+ str(len(outliers)))
# print("max outlier value: "+ str(outliers.max()))
# print("min outlier value: "+ str(outliers.min()))

# for i in outliers.columns:
#    for j in outliers[i]:
#       if(~math.isnan(j)):
#          print(j)

outliers[~np.isnan(outliers)]
# Out:
# /var/folders/zz/xk_p8d9n2f1fmp0kd0jjd9br0000gn/T/ipykernel_26482/2766744770.py:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [248], line 25
#      14 outliers=find_outliers_IQR(data)
#      16 # print("number of outliers: "+ str(len(outliers)))
#      17 # print("max outlier value: "+ str(outliers.max()))
#      18 # print("min outlier value: "+ str(outliers.min()))
#    (...)
#      22 #       if(~math.isnan(j)):
#      23 #          print(j)
# ---> 25 outliers[~np.isnan(outliers)]
#
# ...

# %%
x=data.iloc[: , :-1]
y=data["Loan_Status"].map(dict(Y=1, N=0))
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.3,random_state=42)

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
# train the model with standerd Scaler
